# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">ML-3 GA_ExamPaper_40 Marks </h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage , dendrogram, fcluster,cophenet
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.decomposition import TruncatedSVD
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from surprise import KNNWithMeans,SVDpp
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split,cross_validate

# %% [markdown]
# ### We combined two datasets in single CSV file. Use the below script to seperate the data.
# #### Use data_dime for dimensionality reduction and data_recom for recommendation system.

# %%
data=pd.read_csv('data_set.csv')

data_dime=data.iloc[0:955,0:24]

data_recom=data.iloc[:,24:28]
# Out:
# /home/gl_jupyter/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Section A - 5 Marks </h1>

# %% [markdown]
# ### 1. Data Preprocessing

# %% [markdown]
# ### 1.a. Read the dataset and perform required cleaning and preprocessing prior to model building. Justify the pre-processing approaches used. (3 Marks)

# %%
import pandas as pd
data=pd.read_csv('data_set.csv')
data_dime=data.iloc[0:955,0:24]
data_recom = data.iloc[:, 24:28]
# Out:
# /home/gl_jupyter/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_recom.shape
# Out:
# (85724, 4)

# %%
data_dime.shape
# Out:
# (955, 24)

# %%
data_recom.head()
# Out:
#    UserID  ItemID  Rating  Timestamp
# 0     905     470       1  889325071
# 1     697    1518       5  879835275
# 2     855    1687       5  875638677
# 3     950    1447       5  877420720
# 4     806    1170       4  879889337

# %%
data.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    61.8750      12.00  32.077140   0.755673  449.71875   1.345392
# 1    14.0625       7.50  16.749615   0.629887   56.30625   1.615692
# 2    11.8125      15.75  13.560380   0.807250  127.96875   1.574249
# 3    20.2500       9.75  21.604931   0.545166  258.86250   1.529404
# 4    13.5000      11.25  15.744046   0.684401  127.23750   1.334365
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_19   Feature_20  \
# 0   1.000000   0.758333   2.339759   14.650000  ...  276.318695  65971.18750
# 1   0.900000   0.693333   2.105107    7.850000  ...  318.816223  99969.98438
# 2   0.333333   0.333333   3.415881   11.400000  ...  275.847107  91334.75781
# 3   0.923077   0.494505   3.196538   15.316667  ...  245.214554  48072.80469
# 4   0.866667   0.693333   3.898952   13.400000  ...  252.875107  79794.33594
#
#    Feature_21    Feature_22  Feature_23            Type  UserID  ItemID  \
# 0  15752872.0  368197.28130   19.111872  Non-Infectious     905     470
# 1  31347990.0   13273.56641   19.048378  Non-Infectious     697    1518
# 2  30241724.0   11021.21387   19.080124  Non-Infectious     855    1687
# 3   9425374.0   22393.75195   19.111872  Non-Infectious     950    1447
# 4  25179706.0   13486.62402   19.080124  Non-Infectious     806    1170
#
#    Rating  Timestamp
# 0       1  889325071
# 1       5  879835275
# 2       5  875638677
# 3       5  877420720
# 4       4  879889337
#
# [5 rows x 28 columns]

# %%
data_dime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Feature_1   955 non-null    float64
#  1   Feature_2   955 non-null    float64
#  2   Feature_3   955 non-null    float64
#  3   Feature_4   955 non-null    float64
#  4   Feature_5   955 non-null    float64
#  5   Feature_6   955 non-null    float64
#  6   Feature_7   955 non-null    float64
#  7   Feature_8   955 non-null    float64
#  8   Feature_9   955 non-null    float64
#  9   Feature_10  955 non-null    float64
#  10  Feature_11  955 non-null    float64
#  11  Feature_12  955 non-null    float64
#  12  Feature_13  955 non-null    float64
#  13  Feature_14  955 non-null    float64
#  14  Feature_15  955 non-null    float64
#  15  Feature_16  955 non-null    float64
#  16  Feature_17  955 non-null    float64
#  17  Feature_18  955 non-null    float64
#  18  Feature_19  955 non-null    float64
#  19  Feature_20  955 non-null    float64
#  20  Feature_21  955 non-null    float64
#  21  Feature_22  955 non-null    float64
#  22  Feature_23  955 non-null    float64
#  23  Type        955 non-null    object
# dtypes: float64(23), object(1)
# memory usage: 179.2+ KB

# %% [markdown]
# ### 1.b. Keep the input features of data_dime (independent variables) in inp_data_dime and output feature(`Type`) in out.

# %%
inp_data_dime = data_dime.drop(columns=["Type"])
out_data_dime = data_dime.Type

# %% [markdown]
# ### 1.c. Perform univariate and bivariate analysis (2 Marks)

# %%
# Input Features
inp_data_dime.hist(figsize=(20, 25))
plt.tight_layout()
plt.show()

# for col in inp_data_dime.columns

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data_dime.corr(), annot=True)

# %%
# Target Feature Type Analysis
sns.countplot(x=out_data_dime)

# %%
data_dime.is().sum() # No Missing Values
# Out:
# Feature_1     0
# Feature_2     0
# Feature_3     0
# Feature_4     0
# Feature_5     0
# Feature_6     0
# Feature_7     0
# Feature_8     0
# Feature_9     0
# Feature_10    0
# Feature_11    0
# Feature_12    0
# Feature_13    0
# Feature_14    0
# Feature_15    0
# Feature_16    0
# Feature_17    0
# Feature_18    0
# Feature_19    0
# Feature_20    0
# Feature_21    0
# Feature_22    0
# Feature_23    0
# Type          0
# dtype: int64

# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Section B - 20 Marks </h1>

# %% [markdown]
# ### 2.a. Use inp_data_dime. Apply PCA and compute all the possible principle components(PCs). How many PCs are required to reproduce the 95% charecteristics of original data. Plot it with appropriate diagram. Also print the top 5 eigen vectors (5 marks)

# %%
# Standard Scaler 
scaler = StandardScaler()
scaled_inp = scaler.fit_transform(inp_data_dime)

# PCA Analysis
pca = PCA(n_components=0.95)
pca.fit(scaled_inp)

reduced_data = pca.transform(scaled_inp)

# %%
# Plotting first two components
plt.scatter(reduced_data[:, 0], reduced_data[:, 1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principla Component 2")
plt.show()

# %%
# Top Eigen Vectors
print(pca.components_)
# Out:
# [[ 2.02168045e-01  1.93393754e-01  2.45480447e-01  1.67107748e-01
#    1.97487042e-01  2.62332425e-01  2.34738886e-01  2.46179689e-01
#    1.64049181e-01  2.33658952e-01  1.07856510e-01  1.58758766e-01
#    2.34240782e-01  3.12555529e-01  2.07093063e-01 -3.35720749e-02
#    2.58397797e-01  1.87761618e-01  2.46589534e-01  1.74404376e-01
#    1.28991410e-01  1.70799068e-01  2.36720298e-01]
#  [ 3.63074067e-01  1.08665358e-01  2.79248753e-01 -1.12359630e-01
#    3.52872525e-01 -2.99395410e-02 -2.91598201e-02 -7.30578456e-02
#   -5.93692292e-02  1.55291702e-01  3.06225856e-02 -6.88122436e-02
#   -1.36496061e-02 -9.77906658e-02  1.07038033e-02 -1.99984719e-01
#   -3.97756580e-02 -3.33064208e-01 -2.07359640e-01 -3.66297994e-01
#   -3.61156269e-01  3.61589855e-01 -1.11046786e-02]
#  [-2.70576314e-02  3.18776033e-01  5.67353013e-02 -2.04929717e-01
#    9.96159864e-02  1.81801125e-02 -1.56431576e-01 -9.12771132e-02
#    4.17168968e-01  3.65749322e-01  1.84794237e-01 -4.26576973e-01
#   -2.38731252e-01  1.73632633e-04 -2.19069325e-01  2.83431579e-01
#    7.25495871e-02  1.20576616e-01 -2.92550413e-02  9.64039283e-02
#    1.10821534e-01 -3.07405560e-02 -2.38670255e-01]
#  [-2.06558782e-01  5.57699098e-02 -4.86607168e-02 -2.05329363e-01
#   -1.93482401e-01  4.74479433e-02 -1.06504088e-01 -1.28039916e-01
#    3.05532819e-01  8.04744549e-02 -1.23846210e-01 -1.75167183e-01
#    4.20386793e-01  1.55482600e-02  4.11415314e-01  2.23682262e-01
#   -6.82067646e-02 -1.29891352e-01 -1.08716021e-01 -1.86540029e-01
#   -2.03729041e-01 -1.22000405e-01  4.19082567e-01]
#  [ 1.14551763e-01 -4.14156495e-01  1.45680497e-01 -4.40388597e-01
#    4.96392192e-02 -3.79848829e-01  1.76289975e-01  1.97495555e-01
#   -1.11050592e-02 -5.60270375e-02  2.56253171e-01 -6.78519130e-03
#    3.58540795e-02 -2.28163719e-01  2.15205255e-01  2.70118293e-01
#    3.43049208e-02  1.10385878e-01 -8.90902678e-02  1.51372910e-01
#    2.05779202e-01  2.30817041e-01  4.38836499e-02]
#  [ 1.14929258e-01  1.52021126e-01  8.60950920e-02 -7.70647626e-02
#    1.43365907e-01 -4.99594446e-02 -3.14983425e-01 -1.93610085e-01
#   -5.66065812e-02  3.47995797e-02 -4.00287795e-01 -3.30096905e-02
#    1.55694172e-01 -1.62508304e-01  3.51730303e-02 -2.88207324e-01
#   -2.83988554e-01  3.35665196e-01 -2.09962239e-01  2.56203331e-01
#    3.77084196e-01  1.43258347e-01  1.55352791e-01]
#  [ 1.41175369e-01 -6.66017000e-02  2.70739441e-01 -2.88066715e-01
#   -7.71463393e-02  3.29072622e-01 -1.81094467e-01 -3.77860021e-01
#   -7.34640442e-02 -2.08826981e-01 -2.61715071e-01  3.42091140e-01
#   -8.38234063e-02  9.97130359e-02 -7.99592716e-02  3.94882624e-01
#    3.23430114e-01  2.12299813e-02  2.82603682e-02 -5.39737712e-03
#   -6.59519109e-03  5.75136475e-02 -8.04936604e-02]
#  [-3.06067482e-02 -1.19857942e-01  1.89540835e-01 -2.39990843e-01
#   -9.20801410e-02 -5.82215155e-02  4.65341694e-01  2.60310319e-01
#    2.46732568e-01  1.09133318e-01 -6.35326848e-01 -6.34320400e-02
#   -8.98866040e-02  5.02579853e-02 -2.06036811e-01 -1.62536539e-01
#    1.44341936e-02  1.22607933e-03 -2.03231444e-02 -6.21135093e-02
#   -5.74350342e-02 -1.48698384e-01 -7.20175453e-02]
#  [-3.21375638e-02 -1.34873585e-01  2.65189775e-01 -3.46683174e-01
#   -1.94293040e-01  3.20846637e-01  2.24100554e-01 -3.32608887e-01
#   -1.09027294e-01 -1.24622594e-02  3.91121090e-01 -1.74418111e-01
#    6.48698679e-02  9.07651999e-02 -1.08746115e-01 -4.04663287e-01
#   -2.21972785e-01  5.63067158e-02  1.20905215e-01  5.78257800e-02
#    1.34647577e-02 -1.74319938e-01  6.54386710e-02]
#  [-4.88495028e-02 -1.02650928e-02 -1.06016090e-01  3.97052676e-02
#    8.33699758e-03  6.63618974e-03  1.32132563e-01 -6.68485111e-02
#   -7.51879257e-02  1.07942305e-02  1.34821056e-01 -2.16136446e-02
#    5.78723032e-02  6.01858551e-02 -4.44203380e-02 -1.68611240e-01
#    5.27389413e-01  3.05013627e-01 -6.86540679e-01 -1.67443062e-01
#    2.92972510e-02 -1.63589257e-01  5.19146004e-02]]

# %% [markdown]
# ### 2.b. Create a random matrix (M) of size 20x8 and compute singular values, left singular matrix and right singular matrix using Singular Value Decomposition. Try to reproduce the M back using singluar values and vectors. (5 Marks)

# %%
M = np.random.rand(20, 8)

# SVD of M
U, Sigma, VT = np.linalg.svd(M)

# Reproduce M
sigma_matrix = np.zeros((20,8))
np.fill_diagonal(sigma_matrix, Sigma)
M_reconstruct = U @ sigma_matrix @ VT

# Verify M
result = np.allclose(M, M_reconstruct)
print("Actual M and Reconstructed M are equal: ", result)
# Out:
# Actual M and Reconstructed M are equal:  True

# %%
U.shape, sigma_matrix.shape, VT.shape, M.shape
# Out:
# ((20, 20), (20, 8), (8, 8), (20, 8))

# %% [markdown]
# ### 2.c. Apply SVD on inp_data_dime and compare the SVD transform data with PCA transformed data. Also compare the top 5 singular vectors with eigen vector. How many Singular vectors are required to reproduce the 95% charecteristics of original data.(5 Marks)

# %%
# Apply SVD 
svd = TruncatedSVD()
svd.fit_transform(scaled_inp)

explained_variance = svd.explained_variance_ratio_.cumsum()
n_95 = (explained_variance >= 0.95 ).argmax() + 1


svd = TruncatedSVD(n_components=n_95)
svd.fit_transform(scaled_inp)
n_svd_components = svd.components_

print("Number of SVD components for 95% variance: ", n_95)
print("Shape of Singular Vectors: ", n_svd_components.shape)
# Out:
# Number of SVD components for 95% variance:  1
# Shape of Singular Vectors:  (1, 23)

# %%
print("Shape of PCA Components: ", pca.components_.shape)
# Out:
# Shape of PCA Components:  (10, 23)

# %% [markdown]
# ### 2.d. Build the following ML model and compare its performace: (5 Marks)
#     i. ML model with original inp_data_dime and out
#     ii. ML model with inp_data_dime_pca and out
#     iii. ML model with inp_data_dime_svd and out
#     (Note: For pca and svd use the number of components which captures the 95 percent of variance)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

label = LabelEncoder()
label.fit(out_data_dime)
encoded_out = label.transform(out_data_dime)
# Build Logistic Regression Model on Orinigal Data
X_train, X_test, Y_train, Y_test = train_test_split(inp_data_dime, encoded_out, test_size=0.2, random_state=42)

model1 = LogisticRegression()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyl1 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of LogisticRegression Model with Original Data: ", accuracyl1)
# Out:
# Accuracy of LogisticRegression Model with Original Data:  0.9581151832460733

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

label = LabelEncoder()
label.fit(out_data_dime)
encoded_out = label.transform(out_data_dime)
# Build Logistic Regression Model on Orinigal Data
X_train, X_test, Y_train, Y_test = train_test_split(inp_data_dime, encoded_out, test_size=0.2, random_state=42)

model1 = RandomForestClassifier()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyr1 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of RandomForestClassfier Model with Original Data: ", accuracyr1)
# Out:
# Accuracy of RandomForestClassfier Model with Original Data:  0.9842931937172775

# %%
from sklearn.model_selection import train_test_split

pca = PCA(n_components=10)
pca_inp_dime = pca.fit_transform(inp_data_dime)


# Build Logistic Regression Model on PCA Data
test_size=0.2
X_train, X_test, Y_train, Y_test = train_test_split(pca_inp_dime, encoded_out, test_size=test_size, random_state=42)

model1 = LogisticRegression()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyl2 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of LogisticRegression Model with PCA Data: ", accuracyl2)
# Out:
# Accuracy of LogisticRegression Model with PCA Data:  0.8952879581151832

# %%
from sklearn.model_selection import train_test_split

pca = PCA(n_components=10)
pca_inp_dime = pca.fit_transform(inp_data_dime)


# Build Logistic Regression Model on PCA Data
test_size=0.2
X_train, X_test, Y_train, Y_test = train_test_split(pca_inp_dime, encoded_out, test_size=test_size, random_state=42)

model1 = RandomForestClassifier()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyr2 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of RandomForestClassifier Model with PCA Data: ", accuracyr2)
# Out:
# Accuracy of RandomForestClassifier Model with PCA Data:  1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
svd = TruncatedSVD(n_components=1) # we have got this components count from the previous Analysis
svd_inp_dime = svd.fit_transform(inp_data_dime)


# Build Logistic Regression Model on SVD Data
test_size=0.2
X_train, X_test, Y_train, Y_test = train_test_split(svd_inp_dime, encoded_out, test_size=test_size, random_state=42)

model1 = LogisticRegression()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyl3 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of LogisticRegression Model with SVD Data: ", accuracyl3)
# Out:
# Accuracy of LogisticRegression Model with SVD Data:  0.9162303664921466

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
svd = TruncatedSVD(n_components=1) # we have got this components count from the previous Analysis
svd_inp_dime = svd.fit_transform(inp_data_dime)


# Build Logistic Regression Model on SVD Data
test_size=0.2
X_train, X_test, Y_train, Y_test = train_test_split(svd_inp_dime, encoded_out, test_size=test_size, random_state=42)

model1 = RandomForestClassifier()
model1.fit(X_train, Y_train)

Y_pred1 = model1.predict(X_test)
accuracyr3 = accuracy_score(Y_test, Y_pred1)
print("Accuracy of RandomForestClassifier Model with SVD Data: ", accuracyr3)
# Out:
# Accuracy of RandomForestClassifier Model with SVD Data:  0.8743455497382199

# %%
print("LogisticRegression With Origina Data: ", accuracyl1)
print("LogisticRegression with PCA Data: ", accuracyl2)
print("LogisticRegression with SVD Data: ", accuracyl3)
print("RandomForestClassifier with Original Data: ", accuracyr1)
print("RandomForestClassfier with PCA Data: ", accuracyr2)
print("RandomForestClassifier with SVD Data: ", accuracyr3)
# Out:
# LogisticRegression With Origina Data:  0.9581151832460733
# LogisticRegression with PCA Data:  0.8952879581151832
# LogisticRegression with SVD Data:  0.9162303664921466
# RandomForestClassifier with Original Data:  0.9842931937172775
# RandomForestClassfier with PCA Data:  1.0
# RandomForestClassifier with SVD Data:  0.8743455497382199

# %% [markdown]
# **Based on the Above Metrics we can conclude that  RandomForestClassfier with PCA is giving High Accuracy, bu there colud be chances the model is Overfitted due to the Data Set Size and Sample Size**

# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Section C - 15 Marks </h1>

# %% [markdown]
# ### 3 (a) Build the popularity based recommendation system and suggest top 5 items. (5 Marks)
#
# Use the dataset: data_recom

# %%
data_recom=data.iloc[:,24:28]
data_recom.head()
# Out:
#    UserID  ItemID  Rating  Timestamp
# 0     905     470       1  889325071
# 1     697    1518       5  879835275
# 2     855    1687       5  875638677
# 3     950    1447       5  877420720
# 4     806    1170       4  879889337

# %%
item_popularity = data_recom.groupby("ItemID")["Rating"].mean().sort_values(ascending=False)
print("Top 5 Popular Items")
item_popularity.head()
# Out:
# Top 5 Popular Items
# ItemID
# 499    5.0
# 407    5.0
# 394    5.0
# 233    5.0
# 164    5.0
# Name: Rating, dtype: float64

# %% [markdown]
# ### 3 (b) Build collaborative recommendation engine to recommend a top 5 items to the specific user. Measure the model quality in terms of RMSE (10 Marks)
# Use the dataset: data_recom

# %%
from surprise.model_selection import train_test_split
from surprise import SVD

# Reader Object
reader = Reader(rating_scale=(data_recom["Rating"].min(), data["Rating"].max()))
# Load the dataset  and Split for train and test
data_surprise = Dataset.load_from_df(data_recom[["UserID", "ItemID", "Rating"]], reader)

trainset, testset = train_test_split(data_surprise, test_size=0.2)
# Build Model with SVD

model = SVD()
model.fit(trainset)

predictions = model.test(testset)

# Evaluating the RMSE values
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.9376

# %%
# Predict for Specific User
items_rated_by_user = data_recom[data_recom["UserID"] == 855]["ItemID"].values
items = data_recom.ItemID.unique()

items_to_predict = [item for item in items if item not in items_rated_by_user]

predictions_for_user = [model.predict(855, item) for item in items_to_predict]

# %%
predictions_for_user
# Out:
# [Prediction(uid=855, iid=470, r_ui=None, est=2.353169453063357, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1447, r_ui=None, est=3.5855194547736144, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1170, r_ui=None, est=4.570904504255849, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1543, r_ui=None, est=3.991916134500383, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1512, r_ui=None, est=3.6824610334638908, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1622, r_ui=None, est=2.5322355847872364, details={'was_impossible': False}),
#  Prediction(uid=855, iid=376, r_ui=None, est=3.3816911969646273, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1368, r_ui=None, est=3.188618844867892, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1627, r_ui=None, est=4.10340299575652, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1277, r_ui=None, est=3.952477693381508, details={'was_impossible': False}),
#  Prediction(uid=855, iid=494, r_ui=None, est=2.8261095143734303, details={'was_impossible': False}),
#  Prediction(uid=855, iid=551, r_ui=None, est=3.714770780837606, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1629, r_ui=None, est=3.6937791415165386, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1652, r_ui=None, est=3.6435978102838216, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1112, r_ui=None, est=3.6988568544957237, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1525, r_ui=None, est=3.793864291264106, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1463, r_ui=None, est=3.9735462549742757, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1133, r_ui=None, est=3.6014219988837164, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1538, r_ui=None, est=3.4990132943340817, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1584, r_ui=None, est=3.990643176342597, details={'was_impossible': False}),
#  Prediction(uid=855, iid=959, r_ui=None, est=3.3623140982138113, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1408, r_ui=None, est=4.224653745364278, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1186, r_ui=None, est=3.7838055850550383, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1296, r_ui=None, est=3.8102472575665023, details={'was_impossible': False}),
#  Prediction(uid=855, iid=979, r_ui=None, est=2.7969428397518676, details={'was_impossible': False}),
#  Prediction(uid=855, iid=503, r_ui=None, est=3.4562509573064153, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1094, r_ui=None, est=3.905982348573776, details={'was_impossible': False}),
#  Prediction(uid=855, iid=652, r_ui=None, est=3.011060094694987, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1038, r_ui=None, est=2.956418754826846, details={'was_impossible': False}),
#  Prediction(uid=855, iid=757, r_ui=None, est=3.7841668961985584, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1212, r_ui=None, est=4.232341431483042, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1039, r_ui=None, est=4.062048293778639, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1413, r_ui=None, est=3.710925179929188, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1617, r_ui=None, est=3.811178417528543, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1049, r_ui=None, est=4.388785834794474, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1509, r_ui=None, est=4.271677220606613, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1549, r_ui=None, est=3.711579648596838, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1116, r_ui=None, est=3.5916339854608177, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1281, r_ui=None, est=3.9506036494169594, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1179, r_ui=None, est=4.1478751947933565, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1215, r_ui=None, est=3.534203520250253, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1113, r_ui=None, est=3.7762508944483906, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1011, r_ui=None, est=3.0438234531463206, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1206, r_ui=None, est=3.9236872934538294, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1567, r_ui=None, est=3.7679959983835243, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1615, r_ui=None, est=3.3816582855465502, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1334, r_ui=None, est=3.1566690182532007, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1301, r_ui=None, est=3.397110170680685, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1579, r_ui=None, est=3.840163502471036, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1040, r_ui=None, est=3.3534619823535166, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1174, r_ui=None, est=4.241310239816319, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1514, r_ui=None, est=3.9773563606976556, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1657, r_ui=None, est=3.051042349026772, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1220, r_ui=None, est=4.176112985794317, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1195, r_ui=None, est=3.8287324753184993, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1307, r_ui=None, est=3.37794854917743, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1377, r_ui=None, est=2.677762836732525, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1573, r_ui=None, est=4.071010365093989, details={'was_impossible': False}),
#  Prediction(uid=855, iid=971, r_ui=None, est=3.473204064561916, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1487, r_ui=None, est=3.4962068809616778, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1043, r_ui=None, est=4.158112157158243, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1457, r_ui=None, est=2.5792793602979, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1374, r_ui=None, est=3.7775753755390746, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1313, r_ui=None, est=3.2357259283754023, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1218, r_ui=None, est=4.156652308340171, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1614, r_ui=None, est=3.6704237208168395, details={'was_impossible': False}),
#  Prediction(uid=855, iid=913, r_ui=None, est=3.4431382631439007, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1496, r_ui=None, est=4.036813780499138, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1556, r_ui=None, est=4.308882863308171, details={'was_impossible': False}),
#  Prediction(uid=855, iid=777, r_ui=None, est=4.549521682742121, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1552, r_ui=None, est=3.3302033194577043, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1618, r_ui=None, est=4.123042125031871, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1455, r_ui=None, est=3.3762502517034942, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1689, r_ui=None, est=4.30980632055794, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1244, r_ui=None, est=2.415116742150192, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1132, r_ui=None, est=3.8107375090350852, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1459, r_ui=None, est=3.613336121666872, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1504, r_ui=None, est=3.768287021162399, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1066, r_ui=None, est=3.6149595148783886, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1534, r_ui=None, est=4.0502918552580605, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1489, r_ui=None, est=3.926083363165572, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1292, r_ui=None, est=4.733126770726655, details={'was_impossible': False}),
#  Prediction(uid=855, iid=472, r_ui=None, est=2.1384948306138396, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1560, r_ui=None, est=3.545925497660879, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1308, r_ui=None, est=3.8390534701860792, details={'was_impossible': False}),
#  Prediction(uid=855, iid=909, r_ui=None, est=3.1520239517050657, details={'was_impossible': False}),
#  Prediction(uid=855, iid=995, r_ui=None, est=4.066212623431623, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1211, r_ui=None, est=4.189954283908771, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1572, r_ui=None, est=3.807126338682552, details={'was_impossible': False}),
#  Prediction(uid=855, iid=845, r_ui=None, est=3.3344177535405257, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1071, r_ui=None, est=3.292813724159485, details={'was_impossible': False}),
#  Prediction(uid=855, iid=434, r_ui=None, est=3.0867298038988213, details={'was_impossible': False}),
#  Prediction(uid=855, iid=284, r_ui=None, est=3.2975766460821596, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1224, r_ui=None, est=2.9745324872451526, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1607, r_ui=None, est=4.324429865652689, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1297, r_ui=None, est=3.7100179918499943, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1192, r_ui=None, est=3.6406442770834686, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1644, r_ui=None, est=3.58154222758634, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1539, r_ui=None, est=3.4633987805150164, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1537, r_ui=None, est=3.397454090760416, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1482, r_ui=None, est=3.1165550188539144, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1407, r_ui=None, est=4.132925002713575, details={'was_impossible': False}),
#  Prediction(uid=855, iid=289, r_ui=None, est=2.8891835537262156, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1167, r_ui=None, est=3.535425385620721, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1609, r_ui=None, est=3.6497013298742784, details={'was_impossible': False}),
#  Prediction(uid=855, iid=306, r_ui=None, est=3.23970613670973, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1557, r_ui=None, est=3.503091518041563, details={'was_impossible': False}),
#  Prediction(uid=855, iid=881, r_ui=None, est=2.832356336301343, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1547, r_ui=None, est=4.561422137748995, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1438, r_ui=None, est=3.5687767797042866, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1205, r_ui=None, est=3.5553869884227267, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1445, r_ui=None, est=3.326243308128204, details={'was_impossible': False}),
#  Prediction(uid=855, iid=853, r_ui=None, est=3.740049936553158, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1172, r_ui=None, est=4.343102505344901, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1532, r_ui=None, est=4.274425883695906, details={'was_impossible': False}),
#  Prediction(uid=855, iid=740, r_ui=None, est=3.2119171127677024, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1177, r_ui=None, est=4.1709123269057065, details={'was_impossible': False}),
#  Prediction(uid=855, iid=607, r_ui=None, est=3.4678081731430974, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1432, r_ui=None, est=3.3631481356168056, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1397, r_ui=None, est=3.396172290881668, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1204, r_ui=None, est=4.144581380745632, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1667, r_ui=None, est=3.317068132802139, details={'was_impossible': False}),
#  Prediction(uid=855, iid=758, r_ui=None, est=3.5278329519934513, details={'was_impossible': False}),
#  Prediction(uid=855, iid=885, r_ui=None, est=3.022526964209827, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1575, r_ui=None, est=4.017314454282125, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1194, r_ui=None, est=3.6265996052877814, details={'was_impossible': False}),
#  Prediction(uid=855, iid=851, r_ui=None, est=2.8599495350344246, details={'was_impossible': False}),
#  Prediction(uid=855, iid=581, r_ui=None, est=3.6197643094047045, details={'was_impossible': False}),
#  Prediction(uid=855, iid=976, r_ui=None, est=3.8782179722472634, details={'was_impossible': False}),
#  Prediction(uid=855, iid=208, r_ui=None, est=3.4381499410172656, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1670, r_ui=None, est=3.6457296891541535, details={'was_impossible': False}),
#  Prediction(uid=855, iid=894, r_ui=None, est=3.426843723723688, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1676, r_ui=None, est=3.1155172876996753, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1283, r_ui=None, est=3.327475811818603, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1685, r_ui=None, est=3.4991623293305985, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1330, r_ui=None, est=2.7285318006989385, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1291, r_ui=None, est=2.9455319330692227, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1386, r_ui=None, est=2.8169146942589034, details={'was_impossible': False}),
#  Prediction(uid=855, iid=742, r_ui=None, est=3.9019764391701166, details={'was_impossible': False}),
#  Prediction(uid=855, iid=859, r_ui=None, est=2.4633630451903805, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1412, r_ui=None, est=4.108870071167434, details={'was_impossible': False}),
#  Prediction(uid=855, iid=862, r_ui=None, est=3.403262421761529, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1037, r_ui=None, est=3.7241067600807973, details={'was_impossible': False}),
#  Prediction(uid=855, iid=998, r_ui=None, est=3.096061097288279, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1546, r_ui=None, est=3.4862660595422152, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1533, r_ui=None, est=3.0270257762508783, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1502, r_ui=None, est=4.424997105633999, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1490, r_ui=None, est=4.439985936857279, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1608, r_ui=None, est=3.235211904484358, details={'was_impossible': False}),
#  Prediction(uid=855, iid=997, r_ui=None, est=3.2733276671603466, details={'was_impossible': False}),
#  Prediction(uid=855, iid=482, r_ui=None, est=3.6652257449089642, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1516, r_ui=None, est=3.6591413214781117, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1189, r_ui=None, est=4.25045115933451, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1613, r_ui=None, est=4.13593851327459, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1507, r_ui=None, est=3.8839686825784847, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1642, r_ui=None, est=3.7524118726118707, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1420, r_ui=None, est=3.160338630998845, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1171, r_ui=None, est=3.6383911010795487, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1268, r_ui=None, est=4.177750737337959, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1586, r_ui=None, est=4.3570525209704725, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1196, r_ui=None, est=3.630320106269942, details={'was_impossible': False}),
#  Prediction(uid=855, iid=680, r_ui=None, est=4.049196486651843, details={'was_impossible': False}),
#  Prediction(uid=855, iid=753, r_ui=None, est=3.304865019350323, details={'was_impossible': False}),
#  Prediction(uid=855, iid=700, r_ui=None, est=3.009303999064831, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1596, r_ui=None, est=2.7039744743003737, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1674, r_ui=None, est=3.3314587747898634, details={'was_impossible': False}),
#  Prediction(uid=855, iid=378, r_ui=None, est=3.115275101900563, details={'was_impossible': False}),
#  Prediction(uid=855, iid=814, r_ui=None, est=3.392960647731876, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1173, r_ui=None, est=4.139998451280399, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1078, r_ui=None, est=3.076005769774367, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1226, r_ui=None, est=4.147419515308106, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1115, r_ui=None, est=2.5288689922476184, details={'was_impossible': False}),
#  Prediction(uid=855, iid=739, r_ui=None, est=3.618371713660569, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1053, r_ui=None, est=3.8626363207693335, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1219, r_ui=None, est=4.150889830890006, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1671, r_ui=None, est=2.9638435543298423, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1559, r_ui=None, est=3.6607591803217696, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1521, r_ui=None, est=3.55095154304942, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1222, r_ui=None, est=4.186023311716541, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1553, r_ui=None, est=4.028755679016911, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1440, r_ui=None, est=2.7560407567843046, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1124, r_ui=None, est=3.2270927886310554, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1076, r_ui=None, est=3.9105620666980316, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1635, r_ui=None, est=3.076450477414282, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1168, r_ui=None, est=3.3882683059202963, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1267, r_ui=None, est=3.498785803472166, details={'was_impossible': False}),
#  Prediction(uid=855, iid=785, r_ui=None, est=3.786589805889821, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1239, r_ui=None, est=3.6123174893706156, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1298, r_ui=None, est=3.708539704883163, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1678, r_ui=None, est=4.584888245158755, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1198, r_ui=None, est=3.8579270722256345, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1052, r_ui=None, est=3.979779268575816, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1082, r_ui=None, est=3.0746570745967343, details={'was_impossible': False}),
#  Prediction(uid=855, iid=992, r_ui=None, est=2.9889273636566056, details={'was_impossible': False}),
#  Prediction(uid=855, iid=794, r_ui=None, est=3.2942047659917413, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1305, r_ui=None, est=2.4553346571530708, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1370, r_ui=None, est=3.4079967583033417, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1060, r_ui=None, est=3.0319736151769128, details={'was_impossible': False}),
#  Prediction(uid=855, iid=898, r_ui=None, est=2.924355486138951, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1336, r_ui=None, est=2.6880911602604503, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1633, r_ui=None, est=3.08475998744276, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1452, r_ui=None, est=3.62093826289887, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1663, r_ui=None, est=3.2459569706568145, details={'was_impossible': False}),
#  Prediction(uid=855, iid=952, r_ui=None, est=3.129383607694084, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1367, r_ui=None, est=3.9260634701275663, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1394, r_ui=None, est=4.09519855361135, details={'was_impossible': False}),
#  Prediction(uid=855, iid=855, r_ui=None, est=3.5770668801159453, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1393, r_ui=None, est=3.6299096837503555, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1517, r_ui=None, est=3.9095168954123967, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1183, r_ui=None, est=3.762286517104263, details={'was_impossible': False}),
#  Prediction(uid=855, iid=954, r_ui=None, est=3.8135515248535534, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1630, r_ui=None, est=3.442480633898317, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1304, r_ui=None, est=2.64458220307213, details={'was_impossible': False}),
#  Prediction(uid=855, iid=336, r_ui=None, est=3.412773097930583, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1506, r_ui=None, est=4.358083843676271, details={'was_impossible': False}),
#  Prediction(uid=855, iid=665, r_ui=None, est=3.199048589664354, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1345, r_ui=None, est=3.376515972098648, details={'was_impossible': False}),
#  Prediction(uid=855, iid=872, r_ui=None, est=2.9333767474330243, details={'was_impossible': False}),
#  Prediction(uid=855, iid=543, r_ui=None, est=3.1622682118955208, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1238, r_ui=None, est=3.8228381925101647, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1152, r_ui=None, est=2.8530361916367872, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1274, r_ui=None, est=3.3529724981917237, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1086, r_ui=None, est=3.4002028830531974, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1378, r_ui=None, est=2.717537416736982, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1696, r_ui=None, est=3.474109509814837, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1564, r_ui=None, est=4.224167316612555, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1503, r_ui=None, est=3.9115960305220794, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1178, r_ui=None, est=3.950003081866007, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1073, r_ui=None, est=3.237825691012161, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1232, r_ui=None, est=3.7344425623654836, details={'was_impossible': False}),
#  Prediction(uid=855, iid=704, r_ui=None, est=2.8546473955644065, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1138, r_ui=None, est=3.4604458765568062, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1686, r_ui=None, est=3.982250665160481, details={'was_impossible': False}),
#  Prediction(uid=855, iid=769, r_ui=None, est=1.9942486673127673, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1520, r_ui=None, est=3.7270292788537036, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1047, r_ui=None, est=3.7132481776792994, details={'was_impossible': False}),
#  Prediction(uid=855, iid=919, r_ui=None, est=3.7731277529807206, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1436, r_ui=None, est=3.148965526880136, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1698, r_ui=None, est=3.5247273937300485, details={'was_impossible': False}),
#  Prediction(uid=855, iid=984, r_ui=None, est=3.258536945931909, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1480, r_ui=None, est=3.5976267128016617, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1601, r_ui=None, est=3.4023542552314225, details={'was_impossible': False}),
#  Prediction(uid=855, iid=781, r_ui=None, est=3.7301409465706645, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1568, r_ui=None, est=3.892305255894685, details={'was_impossible': False}),
#  Prediction(uid=855, iid=922, r_ui=None, est=3.2316035219645602, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1626, r_ui=None, est=3.114187873735471, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1632, r_ui=None, est=3.29885358339318, details={'was_impossible': False}),
#  Prediction(uid=855, iid=942, r_ui=None, est=2.5760904945391268, details={'was_impossible': False}),
#  Prediction(uid=855, iid=207, r_ui=None, est=2.983776029174165, details={'was_impossible': False}),
#  Prediction(uid=855, iid=985, r_ui=None, est=2.394319232661198, details={'was_impossible': False}),
#  Prediction(uid=855, iid=599, r_ui=None, est=3.5688118209701445, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1655, r_ui=None, est=3.829594087313638, details={'was_impossible': False}),
#  Prediction(uid=855, iid=779, r_ui=None, est=3.8504228952452544, details={'was_impossible': False}),
#  Prediction(uid=855, iid=833, r_ui=None, est=3.6675104684846436, details={'was_impossible': False}),
#  Prediction(uid=855, iid=590, r_ui=None, est=3.177048594028576, details={'was_impossible': False}),
#  Prediction(uid=855, iid=824, r_ui=None, est=2.6957920033075338, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1217, r_ui=None, est=4.412868292778241, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1395, r_ui=None, est=3.5830214649121266, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1001, r_ui=None, est=3.8696759155408262, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1542, r_ui=None, est=2.6542757885039854, details={'was_impossible': False}),
#  Prediction(uid=855, iid=517, r_ui=None, est=2.879915767456814, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1428, r_ui=None, est=3.799536987109327, details={'was_impossible': False}),
#  Prediction(uid=855, iid=582, r_ui=None, est=3.6939245205537783, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1200, r_ui=None, est=3.848139965883499, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1090, r_ui=None, est=3.5117061448377282, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1692, r_ui=None, est=4.049668598673478, details={'was_impossible': False}),
#  Prediction(uid=855, iid=480, r_ui=None, est=3.627831782818756, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1182, r_ui=None, est=3.3618602221722744, details={'was_impossible': False}),
#  Prediction(uid=855, iid=795, r_ui=None, est=3.352864395593085, details={'was_impossible': False}),
#  Prediction(uid=855, iid=813, r_ui=None, est=4.331527030359747, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1095, r_ui=None, est=3.6799465951027917, details={'was_impossible': False}),
#  Prediction(uid=855, iid=876, r_ui=None, est=2.92066862901605, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1343, r_ui=None, est=3.6953417853918156, details={'was_impossible': False}),
#  Prediction(uid=855, iid=401, r_ui=None, est=3.4326827505062325, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1501, r_ui=None, est=4.3001642351014, details={'was_impossible': False}),
#  Prediction(uid=855, iid=782, r_ui=None, est=3.0172065098910466, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1659, r_ui=None, est=2.733505540984424, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1225, r_ui=None, est=3.478130660534784, details={'was_impossible': False}),
#  Prediction(uid=855, iid=634, r_ui=None, est=3.310821177343236, details={'was_impossible': False}),
#  Prediction(uid=855, iid=540, r_ui=None, est=3.3913106105295325, details={'was_impossible': False}),
#  Prediction(uid=855, iid=600, r_ui=None, est=3.385466601922171, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1227, r_ui=None, est=2.8484257551841026, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1364, r_ui=None, est=2.7871517761735785, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1604, r_ui=None, est=4.233387929415653, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1569, r_ui=None, est=3.5595614224937817, details={'was_impossible': False}),
#  Prediction(uid=855, iid=583, r_ui=None, est=3.293910968429992, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1271, r_ui=None, est=4.278447306552452, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1314, r_ui=None, est=3.037448317491694, details={'was_impossible': False}),
#  Prediction(uid=855, iid=531, r_ui=None, est=4.154078460944571, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1680, r_ui=None, est=3.4646247906500918, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1495, r_ui=None, est=3.6902478262653937, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1513, r_ui=None, est=4.332382451683, details={'was_impossible': False}),
#  Prediction(uid=855, iid=438, r_ui=None, est=3.4548816764988692, details={'was_impossible': False}),
#  Prediction(uid=855, iid=683, r_ui=None, est=3.610090518651328, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1679, r_ui=None, est=2.6947794407360286, details={'was_impossible': False}),
#  Prediction(uid=855, iid=686, r_ui=None, est=2.855785386547344, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1492, r_ui=None, est=4.312820846516696, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1299, r_ui=None, est=2.1957613105785083, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1668, r_ui=None, est=4.363896028981514, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1415, r_ui=None, est=4.641631172579562, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1555, r_ui=None, est=2.8193551860606223, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1127, r_ui=None, est=3.225707108931581, details={'was_impossible': False}),
#  Prediction(uid=855, iid=774, r_ui=None, est=2.9908070782722542, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1265, r_ui=None, est=4.006163526424294, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1045, r_ui=None, est=4.229337257953704, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1021, r_ui=None, est=3.1359067118332433, details={'was_impossible': False}),
#  Prediction(uid=855, iid=684, r_ui=None, est=3.396497619128475, details={'was_impossible': False}),
#  Prediction(uid=855, iid=647, r_ui=None, est=3.9245200209293545, details={'was_impossible': False}),
#  Prediction(uid=855, iid=236, r_ui=None, est=3.5520191866432476, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1479, r_ui=None, est=3.618404689614703, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1451, r_ui=None, est=3.1773808575580764, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1610, r_ui=None, est=3.180586949761494, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1275, r_ui=None, est=3.805820515700997, details={'was_impossible': False}),
#  Prediction(uid=855, iid=725, r_ui=None, est=2.8837007017734084, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1237, r_ui=None, est=3.8076677781317, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1326, r_ui=None, est=3.062562716630842, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1315, r_ui=None, est=3.8312995645234937, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1376, r_ui=None, est=3.8889850902695104, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1104, r_ui=None, est=3.0332416759001894, details={'was_impossible': False}),
#  Prediction(uid=855, iid=986, r_ui=None, est=3.390035986753655, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1079, r_ui=None, est=3.130375051794979, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1620, r_ui=None, est=2.6110446227120065, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1093, r_ui=None, est=3.6377654526809065, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1084, r_ui=None, est=3.8162725162930426, details={'was_impossible': False}),
#  Prediction(uid=855, iid=661, r_ui=None, est=3.978864782586488, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1425, r_ui=None, est=3.5287956709165718, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1606, r_ui=None, est=3.27503884886169, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1603, r_ui=None, est=4.056470220455534, details={'was_impossible': False}),
#  Prediction(uid=855, iid=670, r_ui=None, est=2.603851012480009, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1180, r_ui=None, est=4.279187204884274, details={'was_impossible': False}),
#  Prediction(uid=855, iid=553, r_ui=None, est=3.8881800900264154, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1024, r_ui=None, est=3.2959252583309597, details={'was_impossible': False}),
#  Prediction(uid=855, iid=946, r_ui=None, est=2.9158344198810093, details={'was_impossible': False}),
#  Prediction(uid=855, iid=923, r_ui=None, est=3.4345023798192127, details={'was_impossible': False}),
#  Prediction(uid=855, iid=605, r_ui=None, est=2.4948997490748934, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1000, r_ui=None, est=2.893955491947735, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1403, r_ui=None, est=3.9210351939185384, details={'was_impossible': False}),
#  Prediction(uid=855, iid=563, r_ui=None, est=3.7587349313025404, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1216, r_ui=None, est=4.067015553736893, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1207, r_ui=None, est=4.001582204856283, details={'was_impossible': False}),
#  Prediction(uid=855, iid=701, r_ui=None, est=3.011156355068519, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1467, r_ui=None, est=3.1943579902905985, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1273, r_ui=None, est=4.484436759995181, details={'was_impossible': False}),
#  Prediction(uid=855, iid=953, r_ui=None, est=3.2558915608189514, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1316, r_ui=None, est=2.9115628349939042, details={'was_impossible': False}),
#  Prediction(uid=855, iid=229, r_ui=None, est=3.014717395744675, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1647, r_ui=None, est=2.999726897098413, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1360, r_ui=None, est=3.2528353336356215, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1530, r_ui=None, est=4.205246333485192, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1359, r_ui=None, est=3.0639515586855524, details={'was_impossible': False}),
#  Prediction(uid=855, iid=915, r_ui=None, est=3.3762687882926605, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1628, r_ui=None, est=3.375032412359963, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1381, r_ui=None, est=3.048081003633557, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1598, r_ui=None, est=2.983137189709079, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1653, r_ui=None, est=3.444987700261031, details={'was_impossible': False}),
#  Prediction(uid=855, iid=836, r_ui=None, est=2.819151814616865, details={'was_impossible': False}),
#  Prediction(uid=855, iid=980, r_ui=None, est=2.8545705574380973, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1410, r_ui=None, est=3.529180809001401, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1005, r_ui=None, est=3.1700394414044166, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1309, r_ui=None, est=3.046242949167903, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1382, r_ui=None, est=4.3099075922678995, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1417, r_ui=None, est=3.5825523584990298, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1233, r_ui=None, est=3.5831174406956796, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1161, r_ui=None, est=2.5321623459225644, details={'was_impossible': False}),
#  Prediction(uid=855, iid=752, r_ui=None, est=2.546834993083707, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1672, r_ui=None, est=3.5788979774245044, details={'was_impossible': False}),
#  Prediction(uid=855, iid=889, r_ui=None, est=3.8838615548162068, details={'was_impossible': False}),
#  Prediction(uid=855, iid=944, r_ui=None, est=2.604005902169001, details={'was_impossible': False}),
#  Prediction(uid=855, iid=895, r_ui=None, est=3.6480331605400917, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1446, r_ui=None, est=2.4714049486615894, details={'was_impossible': False}),
#  Prediction(uid=855, iid=622, r_ui=None, est=3.1400010763709267, details={'was_impossible': False}),
#  Prediction(uid=855, iid=860, r_ui=None, est=3.0639315077703446, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1605, r_ui=None, est=3.684627799411556, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1181, r_ui=None, est=3.807522059896852, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1051, r_ui=None, est=3.184214574373693, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1228, r_ui=None, est=3.2343711494757557, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1088, r_ui=None, est=4.157185306244788, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1383, r_ui=None, est=3.4546558331714294, details={'was_impossible': False}),
#  Prediction(uid=855, iid=778, r_ui=None, est=3.786838822118948, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1221, r_ui=None, est=4.316293829043346, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1379, r_ui=None, est=3.883906821636831, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1109, r_ui=None, est=3.4811081087798628, details={'was_impossible': False}),
#  Prediction(uid=855, iid=664, r_ui=None, est=3.219135516030536, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1616, r_ui=None, est=2.6596354571218863, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1571, r_ui=None, est=3.670178882746205, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1157, r_ui=None, est=3.4548432449415976, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1331, r_ui=None, est=2.194502071761682, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1130, r_ui=None, est=3.230867382404935, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1690, r_ui=None, est=3.907737067570355, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1114, r_ui=None, est=3.1834642319328985, details={'was_impossible': False}),
#  Prediction(uid=855, iid=587, r_ui=None, est=3.5459238424413115, details={'was_impossible': False}),
#  Prediction(uid=855, iid=716, r_ui=None, est=2.898187469336167, details={'was_impossible': False}),
#  Prediction(uid=855, iid=394, r_ui=None, est=4.022693992102274, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1433, r_ui=None, est=3.4722744158249603, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1375, r_ui=None, est=2.618300904167932, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1641, r_ui=None, est=4.072509297948845, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1062, r_ui=None, est=3.464541367074029, details={'was_impossible': False}),
#  Prediction(uid=855, iid=956, r_ui=None, est=3.1363243398425444, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1576, r_ui=None, est=4.081805311873144, details={'was_impossible': False}),
#  Prediction(uid=855, iid=386, r_ui=None, est=3.2867834046049427, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1081, r_ui=None, est=3.1557741303586146, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1469, r_ui=None, est=2.605926380884687, details={'was_impossible': False}),
#  Prediction(uid=855, iid=569, r_ui=None, est=3.693412484352518, details={'was_impossible': False}),
#  Prediction(uid=855, iid=633, r_ui=None, est=3.523934616352548, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1522, r_ui=None, est=4.293014281207763, details={'was_impossible': False}),
#  Prediction(uid=855, iid=635, r_ui=None, est=3.355531406584518, details={'was_impossible': False}),
#  Prediction(uid=855, iid=631, r_ui=None, est=3.5490729175557827, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1243, r_ui=None, est=2.2843891945217987, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1637, r_ui=None, est=2.9312628444968998, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1046, r_ui=None, est=4.0922743261080585, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1123, r_ui=None, est=2.335973014252167, details={'was_impossible': False}),
#  Prediction(uid=855, iid=616, r_ui=None, est=3.904665224166683, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1007, r_ui=None, est=3.894241189082076, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1202, r_ui=None, est=4.243819662449825, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1640, r_ui=None, est=3.706080546009583, details={'was_impossible': False}),
#  Prediction(uid=855, iid=293, r_ui=None, est=2.2851132566517816, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1318, r_ui=None, est=3.7872495126285632, details={'was_impossible': False}),
#  Prediction(uid=855, iid=822, r_ui=None, est=2.6945635817469658, details={'was_impossible': False}),
#  Prediction(uid=855, iid=729, r_ui=None, est=3.7521247959071, details={'was_impossible': False}),
#  Prediction(uid=855, iid=458, r_ui=None, est=3.5890163163314166, details={'was_impossible': False}),
#  Prediction(uid=855, iid=584, r_ui=None, est=3.299574966090127, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1150, r_ui=None, est=3.588452745868391, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1523, r_ui=None, est=4.134627805394524, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1475, r_ui=None, est=2.6466870095089865, details={'was_impossible': False}),
#  Prediction(uid=855, iid=834, r_ui=None, est=3.352481336069559, details={'was_impossible': False}),
#  Prediction(uid=855, iid=741, r_ui=None, est=3.6364654769351024, details={'was_impossible': False}),
#  Prediction(uid=855, iid=489, r_ui=None, est=3.368851202986844, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1341, r_ui=None, est=3.492347547512267, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1121, r_ui=None, est=3.0606695627083322, details={'was_impossible': False}),
#  Prediction(uid=855, iid=816, r_ui=None, est=3.437341911574706, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1009, r_ui=None, est=3.3554994700124383, details={'was_impossible': False}),
#  Prediction(uid=855, iid=746, r_ui=None, est=3.346892935603922, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1270, r_ui=None, est=4.1734914685501145, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1391, r_ui=None, est=2.519060285326183, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1325, r_ui=None, est=2.3319165188525197, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1597, r_ui=None, est=2.3732453538630645, details={'was_impossible': False}),
#  Prediction(uid=855, iid=856, r_ui=None, est=3.0378163409482433, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1439, r_ui=None, est=2.3210438119492354, details={'was_impossible': False}),
#  Prediction(uid=855, iid=957, r_ui=None, est=1.9135556176594295, details={'was_impossible': False}),
#  Prediction(uid=855, iid=588, r_ui=None, est=3.2455179518695663, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1508, r_ui=None, est=4.402567431642974, details={'was_impossible': False}),
#  Prediction(uid=855, iid=792, r_ui=None, est=2.8567836203298174, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1673, r_ui=None, est=3.1155426012058456, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1255, r_ui=None, est=3.520105766149884, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1160, r_ui=None, est=2.064730646021422, details={'was_impossible': False}),
#  Prediction(uid=855, iid=354, r_ui=None, est=3.576367264026325, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1041, r_ui=None, est=3.8442513504682534, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1592, r_ui=None, est=3.385125274169211, details={'was_impossible': False}),
#  Prediction(uid=855, iid=693, r_ui=None, est=4.3654028357414445, details={'was_impossible': False}),
#  Prediction(uid=855, iid=571, r_ui=None, est=3.4949429203204376, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1409, r_ui=None, est=3.4355646328218974, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1574, r_ui=None, est=3.8429393341876024, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1249, r_ui=None, est=3.662756409915456, details={'was_impossible': False}),
#  Prediction(uid=855, iid=565, r_ui=None, est=2.8581509824415137, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1624, r_ui=None, est=3.7115208937716972, details={'was_impossible': False}),
#  Prediction(uid=855, iid=618, r_ui=None, est=3.1358096369640696, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1319, r_ui=None, est=3.6375078425884597, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1169, r_ui=None, est=3.715022773974857, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1014, r_ui=None, est=3.878254465791408, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1405, r_ui=None, est=3.053481180327418, details={'was_impossible': False}),
#  Prediction(uid=855, iid=372, r_ui=None, est=3.3523828540826024, details={'was_impossible': False}),
#  Prediction(uid=855, iid=561, r_ui=None, est=2.803147181745616, details={'was_impossible': False}),
#  Prediction(uid=855, iid=687, r_ui=None, est=2.671977123577064, details={'was_impossible': False}),
#  Prediction(uid=855, iid=530, r_ui=None, est=3.6588424314884334, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1191, r_ui=None, est=3.90745539876972, details={'was_impossible': False}),
#  Prediction(uid=855, iid=435, r_ui=None, est=2.684847689664747, details={'was_impossible': False}),
#  Prediction(uid=855, iid=965, r_ui=None, est=3.612915309415027, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1461, r_ui=None, est=4.023837573276581, details={'was_impossible': False}),
#  Prediction(uid=855, iid=867, r_ui=None, est=3.1130227887726267, details={'was_impossible': False}),
#  Prediction(uid=855, iid=731, r_ui=None, est=3.7907627770294416, details={'was_impossible': False}),
#  Prediction(uid=855, iid=978, r_ui=None, est=2.8186477865494686, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1266, r_ui=None, est=4.064007482828061, details={'was_impossible': False}),
#  Prediction(uid=855, iid=478, r_ui=None, est=3.0560298093912297, details={'was_impossible': False}),
#  Prediction(uid=855, iid=689, r_ui=None, est=3.0132447817138526, details={'was_impossible': False}),
# ...
#  Prediction(uid=855, iid=403, r_ui=None, est=2.904776101303208, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1562, r_ui=None, est=2.6906448671304033, details={'was_impossible': False}),
#  Prediction(uid=855, iid=533, r_ui=None, est=3.644723262563811, details={'was_impossible': False}),
#  Prediction(uid=855, iid=400, r_ui=None, est=2.6399678442764953, details={'was_impossible': False}),
#  Prediction(uid=855, iid=254, r_ui=None, est=3.41261588031753, details={'was_impossible': False}),
#  Prediction(uid=855, iid=916, r_ui=None, est=3.083062012626833, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1111, r_ui=None, est=3.7739277432518703, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1335, r_ui=None, est=3.4006284064870838, details={'was_impossible': False}),
#  Prediction(uid=855, iid=557, r_ui=None, est=3.9392623567535368, details={'was_impossible': False}),
#  Prediction(uid=855, iid=934, r_ui=None, est=3.7044919400529, details={'was_impossible': False}),
#  Prediction(uid=855, iid=666, r_ui=None, est=2.6159811738535814, details={'was_impossible': False}),
#  Prediction(uid=855, iid=406, r_ui=None, est=3.2973378331252774, details={'was_impossible': False}),
#  Prediction(uid=855, iid=327, r_ui=None, est=3.578495167777632, details={'was_impossible': False}),
#  Prediction(uid=855, iid=211, r_ui=None, est=2.9767636739290295, details={'was_impossible': False}),
#  Prediction(uid=855, iid=612, r_ui=None, est=2.2979823479255717, details={'was_impossible': False}),
#  Prediction(uid=855, iid=711, r_ui=None, est=2.8113170937951293, details={'was_impossible': False}),
#  Prediction(uid=855, iid=925, r_ui=None, est=2.7740981452862905, details={'was_impossible': False}),
#  Prediction(uid=855, iid=658, r_ui=None, est=3.335435522356274, details={'was_impossible': False}),
#  Prediction(uid=855, iid=615, r_ui=None, est=2.802834524506999, details={'was_impossible': False}),
#  Prediction(uid=855, iid=416, r_ui=None, est=2.9912308616484666, details={'was_impossible': False}),
#  Prediction(uid=855, iid=227, r_ui=None, est=3.110955457854553, details={'was_impossible': False}),
#  Prediction(uid=855, iid=397, r_ui=None, est=2.516554969920425, details={'was_impossible': False}),
#  Prediction(uid=855, iid=927, r_ui=None, est=3.336140115876426, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1117, r_ui=None, est=2.7331706562512257, details={'was_impossible': False}),
#  Prediction(uid=855, iid=819, r_ui=None, est=3.0994103685631607, details={'was_impossible': False}),
#  Prediction(uid=855, iid=171, r_ui=None, est=3.6561687988036087, details={'was_impossible': False}),
#  Prediction(uid=855, iid=525, r_ui=None, est=3.57002545321842, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1106, r_ui=None, est=2.7103324053398556, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1682, r_ui=None, est=3.5657618903020722, details={'was_impossible': False}),
#  Prediction(uid=855, iid=426, r_ui=None, est=2.8020598534439918, details={'was_impossible': False}),
#  Prediction(uid=855, iid=730, r_ui=None, est=3.323935488769746, details={'was_impossible': False}),
#  Prediction(uid=855, iid=221, r_ui=None, est=3.4392914030655297, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1159, r_ui=None, est=3.0803215924633154, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1324, r_ui=None, est=3.0506697582743563, details={'was_impossible': False}),
#  Prediction(uid=855, iid=297, r_ui=None, est=3.9069455881014252, details={'was_impossible': False}),
#  Prediction(uid=855, iid=333, r_ui=None, est=3.5132607877882647, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1312, r_ui=None, est=3.02914555670132, details={'was_impossible': False}),
#  Prediction(uid=855, iid=863, r_ui=None, est=3.996406837194425, details={'was_impossible': False}),
#  Prediction(uid=855, iid=391, r_ui=None, est=3.1390646876503836, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1551, r_ui=None, est=3.087625042406969, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1144, r_ui=None, est=2.9214766469648668, details={'was_impossible': False}),
#  Prediction(uid=855, iid=404, r_ui=None, est=3.320778278932814, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1135, r_ui=None, est=2.781659117007846, details={'was_impossible': False}),
#  Prediction(uid=855, iid=655, r_ui=None, est=3.20254570840807, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1444, r_ui=None, est=4.213229262620165, details={'was_impossible': False}),
#  Prediction(uid=855, iid=534, r_ui=None, est=3.016655741309, details={'was_impossible': False}),
#  Prediction(uid=855, iid=547, r_ui=None, est=3.483214173017761, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1089, r_ui=None, est=3.690440203274643, details={'was_impossible': False}),
#  Prediction(uid=855, iid=273, r_ui=None, est=3.4129413168208953, details={'was_impossible': False}),
#  Prediction(uid=855, iid=315, r_ui=None, est=3.5061599980317673, details={'was_impossible': False}),
#  Prediction(uid=855, iid=843, r_ui=None, est=3.5941526791286185, details={'was_impossible': False}),
#  Prediction(uid=855, iid=878, r_ui=None, est=3.4245247714529214, details={'was_impossible': False}),
#  Prediction(uid=855, iid=907, r_ui=None, est=3.5905969484391327, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1057, r_ui=None, est=3.0863187815100526, details={'was_impossible': False}),
#  Prediction(uid=855, iid=854, r_ui=None, est=3.126481665298039, details={'was_impossible': False}),
#  Prediction(uid=855, iid=656, r_ui=None, est=3.222677568491593, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1119, r_ui=None, est=3.1061840887796897, details={'was_impossible': False}),
#  Prediction(uid=855, iid=682, r_ui=None, est=3.3961157448004764, details={'was_impossible': False}),
#  Prediction(uid=855, iid=838, r_ui=None, est=2.1201309035279015, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1499, r_ui=None, est=3.843386409958926, details={'was_impossible': False}),
#  Prediction(uid=855, iid=542, r_ui=None, est=3.8139530146520455, details={'was_impossible': False}),
#  Prediction(uid=855, iid=733, r_ui=None, est=3.12553647209022, details={'was_impossible': False}),
#  Prediction(uid=855, iid=251, r_ui=None, est=4.325417918402153, details={'was_impossible': False}),
#  Prediction(uid=855, iid=702, r_ui=None, est=3.080601792559899, details={'was_impossible': False}),
#  Prediction(uid=855, iid=585, r_ui=None, est=3.5437384337749207, details={'was_impossible': False}),
#  Prediction(uid=855, iid=715, r_ui=None, est=2.6202844995284753, details={'was_impossible': False}),
#  Prediction(uid=855, iid=469, r_ui=None, est=2.730919603128766, details={'was_impossible': False}),
#  Prediction(uid=855, iid=747, r_ui=None, est=3.6590028863617268, details={'was_impossible': False}),
#  Prediction(uid=855, iid=815, r_ui=None, est=2.5831545541706484, details={'was_impossible': False}),
#  Prediction(uid=855, iid=710, r_ui=None, est=3.251246643997275, details={'was_impossible': False}),
#  Prediction(uid=855, iid=695, r_ui=None, est=3.330530255790863, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1031, r_ui=None, est=2.356242211197739, details={'was_impossible': False}),
#  Prediction(uid=855, iid=262, r_ui=None, est=3.2797769496237072, details={'was_impossible': False}),
#  Prediction(uid=855, iid=832, r_ui=None, est=3.5762772131602376, details={'was_impossible': False}),
#  Prediction(uid=855, iid=632, r_ui=None, est=3.4893225185887893, details={'was_impossible': False}),
#  Prediction(uid=855, iid=481, r_ui=None, est=2.835516248062706, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1033, r_ui=None, est=3.400903157145434, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1155, r_ui=None, est=2.361990533909277, details={'was_impossible': False}),
#  Prediction(uid=855, iid=560, r_ui=None, est=2.49522431213058, details={'was_impossible': False}),
#  Prediction(uid=855, iid=974, r_ui=None, est=2.7131034802541865, details={'was_impossible': False}),
#  Prediction(uid=855, iid=990, r_ui=None, est=3.9934746811550195, details={'was_impossible': False}),
#  Prediction(uid=855, iid=644, r_ui=None, est=3.420532567964818, details={'was_impossible': False}),
#  Prediction(uid=855, iid=176, r_ui=None, est=3.8516927511691756, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1453, r_ui=None, est=2.6182972698675666, details={'was_impossible': False}),
#  Prediction(uid=855, iid=270, r_ui=None, est=3.5347408104131013, details={'was_impossible': False}),
#  Prediction(uid=855, iid=464, r_ui=None, est=3.72197424389113, details={'was_impossible': False}),
#  Prediction(uid=855, iid=414, r_ui=None, est=3.6866508356145973, details={'was_impossible': False}),
#  Prediction(uid=855, iid=339, r_ui=None, est=3.292812238646842, details={'was_impossible': False}),
#  Prediction(uid=855, iid=415, r_ui=None, est=3.35157397676693, details={'was_impossible': False}),
#  Prediction(uid=855, iid=888, r_ui=None, est=3.2650800594334424, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1136, r_ui=None, est=2.216499116036887, details={'was_impossible': False}),
#  Prediction(uid=855, iid=642, r_ui=None, est=3.6256539170943802, details={'was_impossible': False}),
#  Prediction(uid=855, iid=453, r_ui=None, est=3.018833630280429, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1665, r_ui=None, est=2.589406594592218, details={'was_impossible': False}),
#  Prediction(uid=855, iid=685, r_ui=None, est=3.546190774105649, details={'was_impossible': False}),
#  Prediction(uid=855, iid=678, r_ui=None, est=3.358574606219077, details={'was_impossible': False}),
#  Prediction(uid=855, iid=651, r_ui=None, est=2.973549926669065, details={'was_impossible': False}),
#  Prediction(uid=855, iid=173, r_ui=None, est=3.1146645877738206, details={'was_impossible': False}),
#  Prediction(uid=855, iid=703, r_ui=None, est=2.484912944268612, details={'was_impossible': False}),
#  Prediction(uid=855, iid=784, r_ui=None, est=3.2917447101281705, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1664, r_ui=None, est=2.933786555316655, details={'was_impossible': False}),
#  Prediction(uid=855, iid=460, r_ui=None, est=4.135338287067252, details={'was_impossible': False}),
#  Prediction(uid=855, iid=399, r_ui=None, est=3.832294075597077, details={'was_impossible': False}),
#  Prediction(uid=855, iid=326, r_ui=None, est=3.3649344054790036, details={'was_impossible': False}),
#  Prediction(uid=855, iid=552, r_ui=None, est=3.340295625384273, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1590, r_ui=None, est=2.932782931210696, details={'was_impossible': False}),
#  Prediction(uid=855, iid=312, r_ui=None, est=3.4155377741442132, details={'was_impossible': False}),
#  Prediction(uid=855, iid=347, r_ui=None, est=3.518356014988057, details={'was_impossible': False}),
#  Prediction(uid=855, iid=575, r_ui=None, est=3.408491678472828, details={'was_impossible': False}),
#  Prediction(uid=855, iid=215, r_ui=None, est=3.5203755562500194, details={'was_impossible': False}),
#  Prediction(uid=855, iid=170, r_ui=None, est=3.2183920270850948, details={'was_impossible': False}),
#  Prediction(uid=855, iid=663, r_ui=None, est=2.590006170153315, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1140, r_ui=None, est=2.889977550291956, details={'was_impossible': False}),
#  Prediction(uid=855, iid=897, r_ui=None, est=3.1895266462428085, details={'was_impossible': False}),
#  Prediction(uid=855, iid=390, r_ui=None, est=3.0375449507203998, details={'was_impossible': False}),
#  Prediction(uid=855, iid=387, r_ui=None, est=2.8121342906891207, details={'was_impossible': False}),
#  Prediction(uid=855, iid=955, r_ui=None, est=3.966965075923509, details={'was_impossible': False}),
#  Prediction(uid=855, iid=295, r_ui=None, est=3.0576364655847352, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1241, r_ui=None, est=3.7554406526864, details={'was_impossible': False}),
#  Prediction(uid=855, iid=619, r_ui=None, est=3.4340939189058277, details={'was_impossible': False}),
#  Prediction(uid=855, iid=231, r_ui=None, est=3.2802693115549206, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1585, r_ui=None, est=3.4685550800082168, details={'was_impossible': False}),
#  Prediction(uid=855, iid=313, r_ui=None, est=3.4284594712313905, details={'was_impossible': False}),
#  Prediction(uid=855, iid=164, r_ui=None, est=3.5808567282145476, details={'was_impossible': False}),
#  Prediction(uid=855, iid=118, r_ui=None, est=3.0298396175831, details={'was_impossible': False}),
#  Prediction(uid=855, iid=357, r_ui=None, est=3.31916591209415, details={'was_impossible': False}),
#  Prediction(uid=855, iid=243, r_ui=None, est=3.4381499410172656, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1363, r_ui=None, est=3.2486108636956486, details={'was_impossible': False}),
#  Prediction(uid=855, iid=296, r_ui=None, est=3.622357671217259, details={'was_impossible': False}),
#  Prediction(uid=855, iid=706, r_ui=None, est=3.2960136824623203, details={'was_impossible': False}),
#  Prediction(uid=855, iid=549, r_ui=None, est=2.847092455112899, details={'was_impossible': False}),
#  Prediction(uid=855, iid=624, r_ui=None, est=2.7735333047669957, details={'was_impossible': False}),
#  Prediction(uid=855, iid=157, r_ui=None, est=3.652368422732219, details={'was_impossible': False}),
#  Prediction(uid=855, iid=238, r_ui=None, est=3.610593965358321, details={'was_impossible': False}),
#  Prediction(uid=855, iid=539, r_ui=None, est=3.654253950238013, details={'was_impossible': False}),
#  Prediction(uid=855, iid=268, r_ui=None, est=3.320397327294891, details={'was_impossible': False}),
#  Prediction(uid=855, iid=429, r_ui=None, est=3.0470120565612864, details={'was_impossible': False}),
#  Prediction(uid=855, iid=523, r_ui=None, est=2.713518163865961, details={'was_impossible': False}),
#  Prediction(uid=855, iid=477, r_ui=None, est=3.3451533489287177, details={'was_impossible': False}),
#  Prediction(uid=855, iid=608, r_ui=None, est=2.6675681422461595, details={'was_impossible': False}),
#  Prediction(uid=855, iid=614, r_ui=None, est=3.9023082621673084, details={'was_impossible': False}),
#  Prediction(uid=855, iid=398, r_ui=None, est=3.204891675728576, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1101, r_ui=None, est=2.9358330770989824, details={'was_impossible': False}),
#  Prediction(uid=855, iid=257, r_ui=None, est=3.650303369361246, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1059, r_ui=None, est=3.9063538721347735, details={'was_impossible': False}),
#  Prediction(uid=855, iid=999, r_ui=None, est=3.7847253196427353, details={'was_impossible': False}),
#  Prediction(uid=855, iid=994, r_ui=None, est=3.268700123945062, details={'was_impossible': False}),
#  Prediction(uid=855, iid=786, r_ui=None, est=2.99179497063195, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1570, r_ui=None, est=2.6893267644235284, details={'was_impossible': False}),
#  Prediction(uid=855, iid=505, r_ui=None, est=3.063898544754681, details={'was_impossible': False}),
#  Prediction(uid=855, iid=283, r_ui=None, est=3.316168734736943, details={'was_impossible': False}),
#  Prediction(uid=855, iid=1107, r_ui=None, est=3.3008000481738566, details={'was_impossible': False}),
#  Prediction(uid=855, iid=343, r_ui=None, est=3.5960780406737465, details={'was_impossible': False}),
#  Prediction(uid=855, iid=324, r_ui=None, est=2.9694346058311196, details={'was_impossible': False}),
#  Prediction(uid=855, iid=122, r_ui=None, est=3.2485849019947377, details={'was_impossible': False}),
#  Prediction(uid=855, iid=304, r_ui=None, est=3.817521430607204, details={'was_impossible': False}),
#  Prediction(uid=855, iid=302, r_ui=None, est=3.539719583796102, details={'was_impossible': False}),
#  Prediction(uid=855, iid=405, r_ui=None, est=3.1715630746086867, details={'was_impossible': False}),
#  ...]

# %%
predictions_for_user.sort(key=lambda x: x.est, reverse=True)
# Top 5 Items which can be recommended for user 855
items_ids = [prediction.iid  for prediction in predictions_for_user[:5]]

items_ids
# Out:
# [1531, 1292, 1415, 1678, 1170]
